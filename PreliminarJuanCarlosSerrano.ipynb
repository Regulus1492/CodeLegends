# %% [markdown]
# ## Misiones de Knoha

# %%
import numpy as np

# %%
list1 = [2,3,4,1,6]

# %%
njounin = list1[0]
a = np.arange(list1[1],list1[2]).tolist()
b = np.arange(list1[3],list1[4]).tolist()
generalcount = len(set(a+b))
print('njounin ',njounin,'generalcount ',generalcount)
# Out:
# njounin  2 generalcount  5

# %%
# Me falto generalizar

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
